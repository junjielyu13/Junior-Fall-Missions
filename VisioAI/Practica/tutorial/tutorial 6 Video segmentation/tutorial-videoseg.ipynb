# %% [markdown]
# ## Tutorial: Video Segmentation

# %% [markdown]
# In this tutorial, we will work with:
#
# -	Video segmentation: Split the video in temporal segments (different events/scenes of the video).
#
# -	Background subtraction: Extract the background images (static) and remove the foreground (parts in movement).

# %% [markdown]
# ## Video segmentation:
#
# Video segmentaion consists of splitting the vídeo in temporal segments (different events of the video).
#
# Recall that the steps to follow are:
# - Obtain the difference between consecutive frames (e.g. by histograms differences)
# - Decide where there is a jump in the frames appearance.
# - Cut video segments.
# - Obtain the foreground image (e.g. using the median filter).
# - Extract the foreground objects of the detected video segments.

# %%
# %matplotlib inline

# %% [markdown]
# Read and visualize the 'italy' video.
#
# In order to read a collection of images, we wil use the function [ImageCollection()](https://scikit-image.org/docs/0.7.0/api/skimage.io.collection.html) that is in the io library.
#
# In order to visualize a collection of images, we wil use the function [animation.FuncAnimation](https://matplotlib.org/2.0.0/api/_as_gen/matplotlib.animation.FuncAnimation.html).
#
# Observe in the following code, how FuncAnimation is used to read and visualize a sequence of frames.
#
# Explore the parameters of animation.FuncAnimation().

# %%
# imports we will need in the notebook:
import matplotlib.pyplot as plt
import numpy as np

import numpy as np
import skimage
from skimage import io
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
# %matplotlib nbagg

ic = io.ImageCollection('images/epfl-sequence/*.png')
        # Reading a sequence of images from a folder


# %matplotlib nbagg 
    #Changing the pluggin is necessary always when visualizing a video!

fig = plt.figure()  # Create figure
im = plt.imshow(ic[0], animated=True) #Visualize the first image

def updatefig1(i):   #Updating the frame visualization
    im.set_array(ic[i*2]) #Changing the content of the canvas
    return im, #to return a tuple!

plt.show()
ani = animation.FuncAnimation(fig, updatefig1, interval=5, blit=True, frames=50, repeat= False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# We can use the difference of histogram of an image and the previous one as a measure to visually distinguish the shots (scenes) in a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage import img_as_float
from skimage.exposure import histogram

# Function for computing the difference of histogram of an image and the previous one
def compute_hist(im, im_prev, hist_im_prev=None):

    [hist_r, bins_r]=histogram((img_as_float(im)[:,:,0]),64)
    [hist_g, bins_g]=histogram((img_as_float(im)[:,:,1]),64)
    [hist_b, bins_b]=histogram((img_as_float(im)[:,:,2]),64)
    hist_im = np.array(hist_r+hist_g+hist_b)
        
    if hist_im_prev is None:
        [hist_r, bins_r]=histogram((img_as_float(im_prev)[:,:,0]),64)
        [hist_g, bins_g]=histogram((img_as_float(im_prev)[:,:,1]),64)
        [hist_b, bins_b]=histogram((img_as_float(im_prev)[:,:,2]),64)
        hist_im_prev = np.array(hist_r+hist_g+hist_b)

    hist_diff = np.mean(np.abs(hist_im_prev - hist_im))
        
    return hist_diff, hist_im_prev


# initialize the data arrays 
xdata = []
ydata = []
prev_hist = None

# %matplotlib inline

for t in range(len(ic)-1):
    # update the data plot
    y, prev_hist = compute_hist(ic[t+1], ic[t])#, hist_im_prev=prev_hist)
    xdata.append(t) # time = x axis
    ydata.append(y) # y axis
    
fig, ax = plt.subplots(1)
plt.plot(xdata, ydata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\skimage\io\collection.py:285, in ImageCollection.__getitem__(self, n)
#     284 try:
# --> 285     self.data[idx] = self.load_func(fname, **kwargs)
#     286 # Account for functions that do not accept an img_num kwarg
#
# File ~\anaconda3\lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#
# File ~\anaconda3\lib\site-packages\skimage\io\manage_plugins.py:207, in call_plugin(kind, *args, **kwargs)
#     204         raise RuntimeError('Could not find the plugin "%s" for %s.' %
#     205                            (plugin, kind))
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\skimage\io\_plugins\imageio_plugin.py:10, in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# File ~\anaconda3\lib\site-packages\imageio\core\functions.py:265, in imread(uri, format, **kwargs)
#     264 # Get reader and read first
# --> 265 reader = read(uri, format, "i", **kwargs)
#     266 with reader:
#
# File ~\anaconda3\lib\site-packages\imageio\core\functions.py:186, in get_reader(uri, format, mode, **kwargs)
#     185 # Return its reader object
# --> 186 return format.get_reader(request)
#
# File ~\anaconda3\lib\site-packages\imageio\core\format.py:170, in Format.get_reader(self, request)
#     167     raise RuntimeError(
#     168         "Format %s cannot read in %s mode" % (self.name, modename)
#     169     )
# --> 170 return self.Reader(self, request)
#
# File ~\anaconda3\lib\site-packages\imageio\core\format.py:221, in Format._BaseReaderWriter.__init__(self, format, request)
#     220 # Open the reader/writer
# --> 221 self._open(**self.request.kwargs.copy())
#
# TypeError: _open() got an unexpected keyword argument 'img_num'
#
# During handling of the above exception, another exception occurred:
#
# error                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\PIL\ImageFile.py:235, in ImageFile.load(self)
#     234 try:
# --> 235     s = read(self.decodermaxblock)
#     236 except (IndexError, struct.error) as e:
#     237     # truncated png/gif
#
# File ~\anaconda3\lib\site-packages\PIL\PngImagePlugin.py:896, in PngImageFile.load_read(self, read_bytes)
#     894 self.fp.read(4)  # CRC
# --> 896 cid, pos, length = self.png.read()
#     898 if cid not in [b"IDAT", b"DDAT", b"fdAT"]:
#
# File ~\anaconda3\lib\site-packages\PIL\PngImagePlugin.py:162, in ChunkStream.read(self)
#     161     pos = self.fp.tell()
# --> 162     length = i32(s)
#     164 if not is_cid(cid):
#
# File ~\anaconda3\lib\site-packages\PIL\_binary.py:85, in i32be(c, o)
#      84 def i32be(c, o=0):
# ---> 85     return unpack_from(">I", c, o)[0]
#
# error: unpack_from requires a buffer of at least 4 bytes for unpacking 4 bytes at offset 0 (actual buffer size is 0)
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py:669, in pil_try_read(im)
#     667 try:
#     668     # this will raise an IOError if the file is not readable
# --> 669     im.getdata()[0]
#     670 except IOError as e:
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:1294, in Image.getdata(self, band)
#    1277 """
#    1278 Returns the contents of this image as a sequence object
#    1279 containing pixel values.  The sequence object is flattened, so
#    (...)
#    1291 :returns: A sequence-like object.
#    1292 """
# -> 1294 self.load()
#    1295 if band is not None:
#
# File ~\anaconda3\lib\site-packages\PIL\ImageFile.py:241, in ImageFile.load(self)
#     240     else:
# --> 241         raise OSError("image file is truncated") from e
#     243 if not s:  # truncated jpeg
#
# OSError: image file is truncated
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 33>()
#      31 get_ipython().run_line_magic('matplotlib', 'inline')
#      33 for t in range(len(ic)-1):
#      34     # update the data plot
# ---> 35     y, prev_hist = compute_hist(ic[t+1], ic[t])#, hist_im_prev=prev_hist)
#      36     xdata.append(t) # time = x axis
#      37     ydata.append(y) # y axis
#
# File ~\anaconda3\lib\site-packages\skimage\io\collection.py:290, in ImageCollection.__getitem__(self, n)
#     288 if "unexpected keyword argument 'img_num'" in str(e):
#     289     del kwargs['img_num']
# --> 290     self.data[idx] = self.load_func(fname, **kwargs)
#     291 else:
#     292     raise
#
# File ~\anaconda3\lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~\anaconda3\lib\site-packages\skimage\io\manage_plugins.py:207, in call_plugin(kind, *args, **kwargs)
#     203     except IndexError:
#     204         raise RuntimeError('Could not find the plugin "%s" for %s.' %
#     205                            (plugin, kind))
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\skimage\io\_plugins\imageio_plugin.py:10, in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# File ~\anaconda3\lib\site-packages\imageio\core\functions.py:265, in imread(uri, format, **kwargs)
#     260     raise TypeError(
#     261         'Invalid keyword argument "mode", ' 'perhaps you mean "pilmode"?'
#     262     )
#     264 # Get reader and read first
# --> 265 reader = read(uri, format, "i", **kwargs)
#     266 with reader:
#     267     return reader.get_data(0)
#
# File ~\anaconda3\lib\site-packages\imageio\core\functions.py:186, in get_reader(uri, format, mode, **kwargs)
#     181     raise ValueError(
#     182         "Could not find a format to read the specified file in %s mode" % modename
#     183     )
#     185 # Return its reader object
# --> 186 return format.get_reader(request)
#
# File ~\anaconda3\lib\site-packages\imageio\core\format.py:170, in Format.get_reader(self, request)
#     166     modename = MODENAMES.get(select_mode, select_mode)
#     167     raise RuntimeError(
#     168         "Format %s cannot read in %s mode" % (self.name, modename)
#     169     )
# --> 170 return self.Reader(self, request)
#
# File ~\anaconda3\lib\site-packages\imageio\core\format.py:221, in Format._BaseReaderWriter.__init__(self, format, request)
#     219 self._request = request
#     220 # Open the reader/writer
# --> 221 self._open(**self.request.kwargs.copy())
#
# File ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py:298, in PNGFormat.Reader._open(self, pilmode, as_gray, ignoregamma)
#     297 def _open(self, pilmode=None, as_gray=False, ignoregamma=True):
# --> 298     return PillowFormat.Reader._open(self, pilmode=pilmode, as_gray=as_gray)
#
# File ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py:135, in PillowFormat.Reader._open(self, pilmode, as_gray)
#     133 if self._im.palette and self._im.palette.dirty:
#     134     self._im.palette.rawmode_saved = self._im.palette.rawmode
# --> 135 pil_try_read(self._im)
#     136 # Store args
#     137 self._kwargs = dict(
#     138     as_gray=as_gray, is_gray=_palette_is_grayscale(self._im)
#     139 )
#
# File ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py:680, in pil_try_read(im)
#     673 pillow_error_message = str(e)
#     674 error_message = (
#     675     'Could not load "%s" \n'
#     676     'Reason: "%s"\n'
#     677     "Please see documentation at: %s"
#     678     % (im.filename, pillow_error_message, site)
#     679 )
# --> 680 raise ValueError(error_message)
#
# ValueError: Could not load ""
# Reason: "image file is truncated"
# Please see documentation at: http://pillow.readthedocs.io/en/latest/installation.html#external-libraries

# %% [markdown]
# **Exercise:** Using the previous plot, define the threshold over the differences of histograms and use it to localize the first and final frames of every shot. Show the images in a single figure.

# %%
# Your solution here

# %% [markdown]
# ## Background Subtraction:
#
# When we want to segment images from a video we can use the Background subtraction algorithm. How dos it work?

# %% [markdown]
# Background Subtraction consists of extracting the background images (static) and removing the foreground (parts in movement)
#
#
# Recall that the steps to follow are:
# - Apply a median filter to all pixels along the temporal axis to estimate the background image (BI). (Why?!)
# - Subtract BI from the current frame
# - Large absolute values are interesting pixels
#
#
# **Algorithm assumption:** We assume that:
# - the foreground pixels change in time is dynamic.
# - the background pixels change in time is static.

# %% [markdown]
# We read the video called 'epfl' from the [“EPFL” data set](https://www.epfl.ch/labs/cvlab/data/data-pom-index-php/).

# %%
#Changing the pluggin is necessary always when visualizing a video!
# %matplotlib nbagg 

ic = io.ImageCollection('images/epfl-sequence/*.png')
        # Reading a sequence of images from a folder


# %matplotlib nbagg 
    #Changing the pluggin is necessary always when visualizing a video!

fig = plt.figure()  # Create figure
im = plt.imshow(ic[0], animated=True) #Visualize the first image

def updatefig1(i):   #Updating the frame visualization
    im.set_array(ic[i*5]) #Changing the content of the canvas
    return im, #to return a tuple!

plt.show()
ani = animation.FuncAnimation(fig, updatefig1, interval=5, blit=True, frames=50, repeat= False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# We know that there is 240 frames in the sequence.
#
# Complete the following code to visualize the following Figure:
#
# <img src="images/video-seg.png">

# %%
# Extract the background image using the median filter of the whole sequence:
...


# Take the frame #20:
frame = ....

# Define the foreground threshold:
foreground_threshold = 


# Define the function to get the foreground image:
def get_foreground(frame, background, foreground_threshold):
    
    ...
    
    return foreground


# Apply the get_foreground funtion to obtain the foreground image:
foreground = ...



# Show the original image, the background image and the foreground image in a Figure:
...
# Out:
#   Input In [10]
#     frame = ....
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Exercise:** Repeat the exercise for the frames 1, 50, 100, 120, 150, 220 and build a figure (6 rows x 3 columns) with the resulting original image, background image and foreground image of these 6 examples.

# %%
# Your solution here
